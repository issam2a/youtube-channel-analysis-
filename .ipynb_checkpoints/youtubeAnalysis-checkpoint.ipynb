# %%
from googleapiclient.discovery import build 
import pandas as pd 
from IPython.display import JSON

#data viz packegs 
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(15,5))

#NLP
from wordcloud import WordCloud, STOPWORDS

# %%
api_key = 'AIzaSyAsjQiw04Cww4NTEmTMUKA22UXylW1oxQY'

# %%
channel_ids =['UCDybamfye5An6p-j1t2YMsg' ,
              'UC7cs8q-gJRlGwj4A8OmCmXg'
           #other chanel ids 
            ]

# %%
api_service_name = "youtube"
api_version = "v3"


# Get credentials and create an API client

youtube = build(
        api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    # Initialize an empty list to store data for each channel
    all_data = []

    # Make a request to the YouTube Data API to get details about the given channels
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",  # These are the parts of the channel resource we want
        id=','.join(channel_ids)  # Convert list of channel IDs to comma-separated string
    )
    response = request.execute()  # Execute the request and get the response

    # Loop through each channel in the response
    for item in response['items']:
        # Extract the relevant data into a dictionary
        data = {
            'channel_name': item['snippet']['title'],  # Channel title (name)
            'subscribers': item['statistics']['subscriberCount'],  # Number of subscribers
            'views': item['statistics']['viewCount'],  # Total views across the channel
            'totalVideos': item['statistics']['videoCount'],  # Total number of videos
            'playListId': item['contentDetails']['relatedPlaylists']['uploads'],  # ID of the default upload playlist
        }

        # Append the channel's data to the list
        all_data.append(data)

    # Convert the list of dictionaries into a pandas DataFrame and return it
    return pd.DataFrame(all_data)

# %%
channel_stats = get_channel_stats(youtube,channel_ids)

# %%
channel_stats
# Out:
#        channel_name subscribers     views totalVideos  \
# 0           Mo Chen      168000   6611544         253
# 1  Alex The Analyst     1070000  50166981         363
#
#                  playListId
# 0  UUDybamfye5An6p-j1t2YMsg
# 1  UU7cs8q-gJRlGwj4A8OmCmXg

# %%
playlist_id= 'UU7cs8q-gJRlGwj4A8OmCmXg'

def get_video_id(youtube, playlist_id):
    # Initialize an empty list to store video IDs
    video_ids = []

    # First API request to get the first page of results
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",  # Request both snippet and content details
        playlistId=playlist_id,         # Playlist ID to fetch videos from
        maxResults=50                   # Max items per request (50 is the API limit)
    )
    response = request.execute()

    # Extract video IDs from the first page of results
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    # Get the nextPageToken (if more videos exist)
    next_page_token = response.get('nextPageToken')

    # Keep requesting while there is a next page
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token  # Fetch the next page
        )
        response = request.execute()

        # Append video IDs from the current page
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        # Update the next_page_token for the next iteration
        next_page_token = response.get('nextPageToken')

    # Return the full list of video IDs
    return video_ids

# %%
video_ids = get_video_id(youtube,playlist_id)

# %%
len(video_ids)
# Out:
# 363

# %%
def get_video_details(youtube, video_ids):
    all_video_info = []

    # YouTube API allows max 50 video IDs per request
    for i in range(0, len(video_ids), 50):
        # Prepare API request to get video details
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",      # The parts of data to retrieve
            id=','.join(video_ids[i:i+50])                 # Join up to 50 video IDs
        )
        response = request.execute()                       # Execute the API call

        # For each video in the response
        for video in response['items']:
            # Define what fields to extract from each section
            stats_to_keep = {
                'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                'statistics': ['viewCount', 'likeCount', 'favoriteCount', 'commentCount'],
                'contentDetails': ['duration', 'definition', 'caption']
            }

            # Create a dictionary to hold the video info
            video_info = {}
            video_info['video_id'] = video['id']  # Save the video ID

            # Extract the desired fields
            for section in stats_to_keep.keys():
                for field in stats_to_keep[section]:
                    try:
                        video_info[field] = video[section][field]
                    except:
                        # If a field is missing, assign None
                        video_info[field] = None

            # Append the video data to the master list
            all_video_info.append(video_info)

    # Return the collected info as a DataFrame
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube , video_ids)
video_df
# Out:
#         video_id      channelTitle  \
# 0    dkU5n0G7FRQ  Alex The Analyst
# 1    kagUDLvrcZ8  Alex The Analyst
# 2    P5uJYPjUtlc  Alex The Analyst
# 3    dStNNjOKML4  Alex The Analyst
# 4    OQM9x6E3ojo  Alex The Analyst
# ..           ...               ...
# 358  4rfr6A3lO-Y  Alex The Analyst
# 359  OTq2NRy_AGs  Alex The Analyst
# 360  ya28cb3zFGE  Alex The Analyst
# 361  Hsi2BG0SOiQ  Alex The Analyst
# 362  6lQzbk6_OTw  Alex The Analyst
#
#                                                  title  \
# 0                Best Resources to Learn Excel in 2025
# 1               Best Resources to Learn Python in 2025
# 2                  Best Resources to Learn SQL in 2025
# 3    How to Practice for General Technical Intervie...
# 4        How to Lie with Data | Biased Data Collection
# ..                                                 ...
# 358  Data Analyst Resume | Reviewing My Resume! | F...
# 359  Working at a Big Company Vs Small Company | To...
# 360      Data Analyst Salary | 100k with No Experience
# 361  Truth About Big Companies | Told by a Fortune ...
# 362                  Top 3 Data Analyst Skills in 2020
#
#                                            description  \
# 0    In this video we take a look at the best resou...
# 1    In this video we take a look at the best resou...
# 2    In this video we take a look at the best resou...
# 3    Try it out here: https://www.analystbuilder.co...
# 4    It's so easy to lie with data!\n\nIn fact, it ...
# ..                                                 ...
# 358  Data Analyst Resume | Reviewing My Resume! | F...
# 359  Working at a Big Company Vs Small Company | To...
# 360  Data Analyst Salary | 100k with No Experience ...
# 361  Truth About Big Companies // There are a ton o...
# 362  Top 3 Data Analyst Skills in 2020 // There are...
#
#                                                   tags           publishedAt  \
# 0    [Data Analyst, Data Analyst job, Data Analyst ...  2025-05-27T12:01:27Z
# 1    [Data Analyst, Data Analyst job, Data Analyst ...  2025-05-20T12:01:32Z
# 2    [Data Analyst, Data Analyst job, Data Analyst ...  2025-05-13T12:00:49Z
# 3    [Data Analyst, Data Analyst job, Data Analyst ...  2025-05-06T12:01:11Z
# 4    [Data Analyst, Data Analyst job, Data Analyst ...  2025-04-29T12:00:46Z
# ..                                                 ...                   ...
# 358  [Data Analyst, How to become a data analyst, D...  2020-01-30T14:07:55Z
# 359  [Data Analyst, How to become a Data Analyst, B...  2020-01-25T16:38:39Z
# 360  [Data Analyst Salary, Data analyst with no exp...  2020-01-23T03:16:09Z
# 361  [Working at a big company, Big company data an...  2020-01-21T03:52:15Z
# 362  [Top skills for data analyst, Top 3 skills for...  2020-01-17T14:31:39Z
#
#     viewCount likeCount favoriteCount commentCount  duration definition  \
# 0        5643       345             0           14   PT4M49S         hd
# 1       15618       619             0           88    PT5M9S         hd
# 2       19152       748             0           35   PT6M11S         hd
# 3        3968       158             0           17  PT10M21S         hd
# 4        2964        91             0           10   PT4M22S         hd
# ..        ...       ...           ...          ...       ...        ...
# 358     80995      1748             0           63   PT7M33S         hd
# 359     15971       426             0           23   PT5M50S         hd
# 360     66246      2238             0          228    PT5M3S         hd
# 361      9717       343             0           20   PT5M45S         hd
# 362     30955      1463             0          143   PT2M40S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 358   false
# 359   false
# 360   false
# 361   false
# 362   false
#
# [363 rows x 13 columns]

# %% [markdown]
# ## Data pre-processing

# %%
video_df.columns
# Out:
# Index(['video_id', 'channelTitle', 'title', 'description', 'tags',
#        'publishedAt', 'viewCount', 'likeCount', 'favoriteCount',
#        'commentCount', 'duration', 'definition', 'caption'],
#       dtype='object')

# %% [markdown]
# finding nulls

# %%
video_df.isnull().sum()
# Out:
# video_id          0
# channelTitle      0
# title             0
# description       0
# tags             11
# publishedAt       0
# viewCount         0
# likeCount         0
# favoriteCount     0
# commentCount      0
# duration          0
# definition        0
# caption           0
# dtype: int64

# %% [markdown]
# Replacing unlls values with None

# %%
video_df['tags'] = video_df['tags'].fillna('None')

# %%
video_df.isnull().sum()
# Out:
# video_id         0
# channelTitle     0
# title            0
# description      0
# tags             0
# publishedAt      0
# viewCount        0
# likeCount        0
# favoriteCount    0
# commentCount     0
# duration         0
# definition       0
# caption          0
# dtype: int64

# %% [markdown]
# checking the data types

# %%
video_df.dtypes
# Out:
# video_id         object
# channelTitle     object
# title            object
# description      object
# tags             object
# publishedAt      object
# viewCount        object
# likeCount        object
# favoriteCount    object
# commentCount     object
# duration         object
# definition       object
# caption          object
# dtype: object

# %% [markdown]
# Convert numeric columns
# Some columns like viewCount, likeCount, etc., come as strings, so we need to convert them to numeric:

# %%
cols_to_convert =['viewCount','likeCount','favoriteCount','commentCount']
for column in cols_to_convert :
    video_df[column] = pd.to_numeric(video_df[column] , errors='coerce')

# %%
video_df.dtypes
# Out:
# video_id         object
# channelTitle     object
# title            object
# description      object
# tags             object
# publishedAt      object
# viewCount         int64
# likeCount         int64
# favoriteCount     int64
# commentCount      int64
# duration         object
# definition       object
# caption          object
# dtype: object

# %% [markdown]
# Parse date column

# %%
video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'])

# %% [markdown]
# Parse video duration (from ISO 8601 to seconds)

# %%
import isodate
video_df['duration'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x).total_seconds() if pd.notnull(x) else None)

# %% [markdown]
# Drop or fix problematic columns
# Always null or zero (e.g., favoriteCount often is)

# %%
video_df=video_df.drop(video_df['favoriteCount'])

# %% [markdown]
#  Remove duplicates

# %%
video_df=video_df.drop_duplicates(subset='video_id')

# %% [markdown]
# Validate data ranges (sanity checks)
# ensure no negative counts or unrealistic values

# %%
video_df = video_df[video_df['viewCount'] > 0 ]

# %% [markdown]
#  Reset index

# %%
video_df = video_df.reset_index(drop=True)

# %% [markdown]
# creating a new column for days of the week

# %%
video_df['publishedAtDayWeek']= video_df['publishedAt'].dt.day_name()

# %% [markdown]
# ## Analysis Ideas

# %% [markdown]
# 1.Channel Performance Summary

# %% [markdown]
# * Total number of videos

# %%
total_vid_count = video_df['video_id'].nunique()
print('total number of videos ',total_vid_count)
# Out:
# total number of videos  362

# %% [markdown]
# 2. Total & Average Views, Likes, Comments

# %%
total_views = video_df['viewCount'].sum()
avg_view = video_df['viewCount'].mean()
print('total_views: ',total_views ,'\n','avg_views: ' , avg_view)
# Out:
# total_views:  50189565
#  avg_views:  138645.20718232045

# %%
total_likes = video_df['likeCount'].sum()
avg_likes = video_df['likeCount'].mean()
print('total_likes: ',total_likes ,'\n','avg_likes: ' , avg_likes)
# Out:
# total_likes:  1205531
#  avg_likes:  3330.196132596685

# %%
total_comments = video_df['commentCount'].sum()
avg_comments = video_df['commentCount'].mean()

print('total_comments: ',total_comments,'\n','avg_comments: ' , avg_comments)
# Out:
# total_comments:  65517
#  avg_comments:  180.98618784530387

# %% [markdown]
# 3.Best preforming videos

# %%
plt.figure(figsize=(14, 6))
sns.barplot(data= video_df[0:9].sort_values('viewCount',ascending=True), x='title' , y= 'viewCount', palette='muted')
sns.set_style('whitegrid')
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1588\2973734458.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= video_df[0:9].sort_values('viewCount',ascending=True), x='title' , y= 'viewCount', palette='muted')

# %% [markdown]
# 4.Visualize Publishing Frequency

# %%
video_df['year_month']  =video_df['publishedAt'].dt.to_period('M').astype(str)
monthly_freq = video_df.groupby('year_month')['video_id'].count()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1588\2030249188.py:1: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   video_df['year_month']  =video_df['publishedAt'].dt.to_period('M').astype(str)

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(x= monthly_freq.index , y= monthly_freq.values )
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# yearly freq uploaded videos

# %%
sns.histplot(video_df['publishedAt'].dt.year , bins=20,kde= True)
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(x='publishedAt', y='viewCount', data=video_df, label='Views')
sns.lineplot(x='publishedAt', y='likeCount', data=video_df, label='Likes')
sns.lineplot(x='publishedAt', y='commentCount', data=video_df, label='Comments')
plt.title(' Engagement Over Time (by Publish Date)')
plt.xlabel('Publish Date')
plt.ylabel('Count')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# This chart shows how frequently videos are uploaded on each weekday

# %%
# Extract the day name
video_df['day_name'] = video_df['publishedAt'].dt.day_name()

# Count videos per day
video_count = video_df.groupby('day_name')['video_id'].count().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

# Plot
plt.figure(figsize=(14, 5))
sns.barplot(x=video_count.index, y=video_count.values, palette='muted')
plt.title('Video Upload Count by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Videos')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1588\1153995229.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=video_count.index, y=video_count.values, palette='muted')

# %% [markdown]
# Trend by Month

# %%
plt.figure(figsize=(14,5))
sns.boxenplot(data=video_df,x=video_df['publishedAt'].dt.month_name() ,y= 'viewCount' , order=['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December'])
plt.title(' Views Distribution by Month')
plt.xticks(rotation= 45) 
plt.tight_layout()
plt.show()

# %%
sns.heatmap(video_df.corr(numeric_only=True) ,annot= True , cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# ## video duration avg

# %%
sns.histplot(video_df['duration'] /60, bins = 20 )
plt.show()

# %% [markdown]
# now we are going to see what words are most repeated in the title of the videos
# using wordcloud package

# %%
# Combine all titles into one stringabs
text = " ".join(title for title in video_df['title'].dropna())
# Generate the word cloud
wordcloud = WordCloud(width=800, height=400,
                      background_color='black',
                      
                      collocations=False,  # treat repeated phrases as individual words
                      colormap='viridis').generate(text)
plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Most Common Words in Video Titles", fontsize=20)
plt.show()

# %%
video_df['tags']
# Out:
# 0      [Data Analyst, Data Analyst job, Data Analyst ...
# 1      [Data Analyst, Data Analyst job, Data Analyst ...
# 2      [Data Analyst, Data Analyst job, Data Analyst ...
# 3      [Data Analyst, Data Analyst job, Data Analyst ...
# 4      [Data Analyst, Data Analyst job, Data Analyst ...
#                              ...
# 357    [Data Analyst, How to become a data analyst, D...
# 358    [Data Analyst, How to become a Data Analyst, B...
# 359    [Data Analyst Salary, Data analyst with no exp...
# 360    [Working at a big company, Big company data an...
# 361    [Top skills for data analyst, Top 3 skills for...
# Name: tags, Length: 362, dtype: object

# %%
video_df['tagsCount'] = video_df['tags'].apply(len)
video_df['tagsCount']
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 357    15
# 358    17
# 359    14
# 360     7
# 361     8
# Name: tagsCount, Length: 362, dtype: int64

# %% [markdown]
# ## lest see if there is any correlation between the number of tages and the viewCount

# %%
sns.scatterplot(data= video_df , x= 'tagsCount' , y='viewCount')
plt.title('Number of Tags vs View Count')
plt.show()

# %% [markdown]
# ## Calculating the correlation

# %%
# Calculate correlation
correlation = video_df['tagsCount'].corr(video_df['viewCount'])
print(f'Correlation: {correlation}')
# Out:
# Correlation: 0.32192918969163903

# %% [markdown]
# A correlation of 0.32 between the number of tags and view count means:
#
# 🔍 Interpretation:
# ✅ Positive correlation: More tags tend to be associated with higher view counts.
#
# ⚠️ Weak to moderate strength: The relationship is real but not strong.

# %% [markdown]
# ## Check for Diminishing Returns Does adding more tags always help? Or is there a "sweet spot"?

# %% [markdown]
# This will show if views drop or flatten after a certain number of tags.

# %%
sns.regplot(data=video_df, x='tagsCount', y='viewCount')
plt.title('Tag Count vs. View Count with Regression Line')
plt.show()

# %%
video_df.groupby('tagsCount')['viewCount'].mean().plot(kind='line')
plt.ylabel('Average View Count')
plt.xlabel('Number of Tags')
plt.title('Average View Count by Number of Tags')
plt.grid(True)
plt.show()

# %% [markdown]
#  ## checking if certain keywords in the tags affect view counts

# %% [markdown]
# * firt we will Define Keywords to Test

# %%
keywords_to_test = ['tutorial', 'python', 'beginner', 'SQL', 'AI','Excel','Data analyst','job']

# %% [markdown]
# * Create Indicator Columns for Each Keyword
#   Mark whether each video has each keyword in its tags:

# %%
for keyword in keywords_to_test:
    video_df[f'has_{keyword}'] = video_df['tags'].apply(lambda tag_list: keyword.lower() in [t.lower() for t in tag_list])

# %% [markdown]
# * Compare View Counts

# %%
for keyword in keywords_to_test:
    col = f'has_{keyword}'
    sns.boxplot(data=video_df, x=col, y='viewCount')
    plt.title(f'View Count Distribution for Tag: "{keyword}"')
    plt.xlabel(f'Does tag list contain "{keyword}"?')
    plt.ylabel('View Count')
    plt.yscale('log')  # Log scale to handle outliers
    plt.show()
